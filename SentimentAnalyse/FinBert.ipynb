# %% [markdown]
# # Sentiment Analyse

# %% [markdown]
# ## Kafka Producer

# %%
import json
import boto3
from kafka.admin import KafkaAdminClient, NewTopic
from kafka import KafkaProducer
from kafka.errors import TopicAlreadyExistsError

# MinIO-Verbindung
s3 = boto3.client(
    's3',
    endpoint_url='http://172.29.16.105:9000',
    aws_access_key_id='bdenggroup3',
    aws_secret_access_key='bdenggroup3'
)

bucket_name = 'bdenggroup3' # S3 bucket
prefix = 'parsed/'          # S3 folder in bucket

# Kafka-Einstellungen
kafka_broker = 'localhost:9092'
topic_name = 'artikel-sentiment'

# Kafka-Topic erstellen, falls es nicht existiert
admin_client = KafkaAdminClient(bootstrap_servers=kafka_broker)
try:
    admin_client.create_topics([NewTopic(name=topic_name, num_partitions=1, replication_factor=1)])
    print(f"✅ Kafka-Topic '{topic_name}' wurde erstellt.")
except TopicAlreadyExistsError:
    print(f"ℹ️ Kafka-Topic '{topic_name}' existiert bereits.")

# Kafka-Producer initialisieren
producer = KafkaProducer(
    bootstrap_servers=kafka_broker,
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

# Alle Dateien im Ordner 'parsed/' aus MinIO lesen und senden
paginator = s3.get_paginator("list_objects_v2")
page_iterator = paginator.paginate(Bucket=bucket_name, Prefix=prefix)

for page in page_iterator:
    for obj in page.get("Contents", []):
        key = obj["Key"]
        if not key.endswith(".json"):
            continue

        content = s3.get_object(Bucket=bucket_name, Key=key)["Body"].read().decode("utf-8")
        parsed_article = json.loads(content)
        # Extrahiere Dateinamen, z.B. parsed_255.json
        filename = key.split("/")[-1]

        # Füge `source`-Feld hinzu
        message = {
            "source": filename,
            "url": parsed_article.get("url"),
            "articleText": parsed_article.get("articleText"),
            "articleTimestamp": parsed_article.get("articleTimestamp"),
            "scrapingTimestamp": parsed_article.get("scrapingTimestamp"),
            "parsingTimestamp": parsed_article.get("parsingTimestamp")
        }

        producer.send(topic_name, message)
        print(f"📤 Gesendet: {key}")

producer.flush()
print("✅ Alle Artikel wurden an Kafka gesendet.")

# %% [markdown]
# ## Kafka Consumer FinBert Sentiment Analyse

# %%
import json
import boto3
import nltk
from kafka import KafkaConsumer
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
from collections import defaultdict
from nltk.tokenize import PunktSentenceTokenizer
import pandas as pd
from datetime import datetime

nltk.download("punkt")
sentence_tokenizer = PunktSentenceTokenizer()

# Ticker + Synonyme laden
ticker_df = pd.read_csv("ticker_synonyme.csv")
ticker_map = defaultdict(set)
for _, row in ticker_df.iterrows():
    ticker_map[row["ticker"]].add(row["synonym"].lower())

# Kafka Consumer
consumer = KafkaConsumer(
    "artikel-sentiment",
    bootstrap_servers="localhost:9092",
    auto_offset_reset="earliest",
    enable_auto_commit=True,
    group_id="finbert-consumer",
    value_deserializer=lambda m: json.loads(m.decode("utf-8"))
)

# FinBERT
model_name = "ProsusAI/finbert"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
classifier = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# MinIO Setup
s3 = boto3.client(
    's3',
    endpoint_url='http://172.29.16.105:9000',
    aws_access_key_id='bdenggroup3',
    aws_secret_access_key='bdenggroup3'
)

bucket_name = 'bdenggroup3'
output_prefix = 'sentiment/'

# Konfiguration
block_size = 3
min_blocks_per_ticker = 2
min_relevance_score = 0.1

for msg in consumer:
    article = msg.value
    text = article.get("articleText")
    if not text:
        print(f"⚠️ Kein Text vorhanden für: {article.get('source')}")
        continue

    sätze = sentence_tokenizer.tokenize(text)
    if len(sätze) == 0:
        continue

    # In Blöcke aufteilen
    blöcke = [sätze[i:i+block_size] for i in range(0, len(sätze), block_size)]
    block_sentences = [" ".join(block) for block in blöcke]
    total_blocks = len(blöcke)

    # Sentimentanalyse pro Block
    block_sentiments = classifier(block_sentences, truncation=True)

    # Ticker-Erkennung pro Block
    ticker_to_blocks = defaultdict(list)
    for idx, block in enumerate(blöcke):
        block_text = " ".join(block).lower()
        for ticker, syns in ticker_map.items():
            if any(syn in block_text for syn in syns):
                ticker_to_blocks[ticker].append(idx)

    # Nur relevante Ticker behalten
    ticker_to_blocks = {
        ticker: idxs for ticker, idxs in ticker_to_blocks.items()
        if len(idxs) >= min_blocks_per_ticker
    }

    if not ticker_to_blocks:
        print(f"ℹ️ Keine ausreichend relevanten Ticker für: {article.get('source')}")
        continue

    # Sentiment & Relevanz berechnen
    tickers_output = []
    for ticker, idx_list in ticker_to_blocks.items():
        sentiment_sum = 0
        score_sum = 0
        for idx in idx_list:
            result = block_sentiments[idx]
            label_weights = {"positive": 1, "neutral": 0, "negative": -1}
            weight = label_weights[result["label"]]
            sentiment_sum += weight * result["score"]
            score_sum += result["score"]

        weighted_sentiment = sentiment_sum / score_sum if score_sum else 0
        relevance_score = len(idx_list) / total_blocks if total_blocks else 0

        if relevance_score >= min_relevance_score:
            tickers_output.append({
                "ticker": ticker,
                "sentiment_score": round(weighted_sentiment, 3),
                "relevance_score": round(relevance_score, 3)
            })

    if not tickers_output:
        print(f"ℹ️ Keine Ticker mit ausreichender Relevanz für: {article.get('source')}")
        continue

    # Ergebnis erzeugen & speichern
    ergebnis = {
        "url": article.get("url"),
        "articleTimestamp": article.get("articleTimestamp"),
        "scrapingTimestamp": article.get("scrapingTimestamp"),
        "parsingTimestamp": article.get("parsingTimestamp"),
        "sentimentTimestamp": datetime.utcnow().isoformat(),
        "tickers": tickers_output
    }

    source_filename = article.get("source", "parsed_unknown.json")
    sentiment_filename = source_filename.replace("parsed_", "sentiment_")
    key = f"{output_prefix}{sentiment_filename}"

    s3.put_object(Bucket=bucket_name, Key=key, Body=json.dumps(ergebnis).encode("utf-8"))
    print(f"✅ Sentiment für {len(tickers_output)} Ticker gespeichert: {key}")

# %% [markdown]
# ## Consumer mit Multithreading

# %%
processed = []

# %%
import json
import boto3
import nltk
import pandas as pd
from kafka import KafkaConsumer
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
from collections import defaultdict
from nltk.tokenize import PunktSentenceTokenizer
from concurrent.futures import ThreadPoolExecutor
from datetime import datetime

# Setup
nltk.download("punkt")
sentence_tokenizer = PunktSentenceTokenizer()

# Ticker + Synonyme laden
ticker_df = pd.read_csv("ticker_synonyme.csv")
ticker_map = defaultdict(set)
for _, row in ticker_df.iterrows():
    ticker_map[row["ticker"]].add(row["synonym"].lower())

# FinBERT
model_name = "ProsusAI/finbert"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
classifier = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# 🪣 MinIO
s3 = boto3.client(
    's3',
    endpoint_url='http://172.29.16.105:9000',
    aws_access_key_id='bdenggroup3',
    aws_secret_access_key='bdenggroup3'
)

bucket_name = 'bdenggroup3'
output_prefix = 'sentiment/'

# 🔧 Konfiguration
block_size = 3
min_blocks_per_ticker = 2
min_relevance_score = 0.1
max_workers = 4

# Kafka
consumer = KafkaConsumer(
    "artikel-sentiment",
    bootstrap_servers="localhost:9092",
    auto_offset_reset="earliest",
    enable_auto_commit=False,
    group_id="finbert-consumer",
    value_deserializer=lambda m: json.loads(m.decode("utf-8"))
)


# Verarbeitung eines Artikels
def process_article(article):
    try:
        source_filename = article.get("source", "parsed_unknown.json")
        sentiment_filename = source_filename.replace("parsed_", "sentiment_")
        key = f"{output_prefix}{sentiment_filename}"

        # 🚫 Duplikate überspringen
        try:
            s3.head_object(Bucket=bucket_name, Key=key)
            print(f"⏭️ Bereits verarbeitet, wird übersprungen: {key}")
            return
        except s3.exceptions.ClientError as e:
            if e.response['Error']['Code'] != '404':
                raise

        text = article.get("articleText")
        if not text:
            print(f"⚠️ Kein Text vorhanden für: {article.get('source')}")
            return

        sätze = sentence_tokenizer.tokenize(text)
        if len(sätze) == 0:
            return

        blöcke = [sätze[i:i+block_size] for i in range(0, len(sätze), block_size)]
        block_sentences = [" ".join(block) for block in blöcke]
        total_blocks = len(blöcke)

        block_sentiments = classifier(block_sentences, truncation=True)

        ticker_to_blocks = defaultdict(list)
        for idx, block in enumerate(blöcke):
            block_text = " ".join(block).lower()
            for ticker, syns in ticker_map.items():
                if any(syn in block_text for syn in syns):
                    ticker_to_blocks[ticker].append(idx)

        ticker_to_blocks = {
            ticker: idxs for ticker, idxs in ticker_to_blocks.items()
            if len(idxs) >= min_blocks_per_ticker
        }

        if not ticker_to_blocks:
            print(f"ℹ️ Keine ausreichend relevanten Ticker für: {article.get('source')}")
            return

        tickers_output = []
        for ticker, idx_list in ticker_to_blocks.items():
            sentiment_sum = 0
            score_sum = 0
            for idx in idx_list:
                result = block_sentiments[idx]
                weight = {"positive": 1, "neutral": 0, "negative": -1}[result["label"]]
                sentiment_sum += weight * result["score"]
                score_sum += result["score"]

            weighted_sentiment = sentiment_sum / score_sum if score_sum else 0
            relevance_score = len(idx_list) / total_blocks if total_blocks else 0

            if relevance_score >= min_relevance_score:
                tickers_output.append({
                    "ticker": ticker,
                    "sentiment_score": round(weighted_sentiment, 3),
                    "relevance_score": round(relevance_score, 3)
                })

        if not tickers_output:
            print(f"ℹ️ Keine Ticker mit ausreichender Relevanz für: {article.get('source')}")
            return

        ergebnis = {
            "url": article.get("url"),
            "articleTimestamp": article.get("articleTimestamp"),
            "scrapingTimestamp": article.get("scrapingTimestamp"),
            "parsingTimestamp": article.get("parsingTimestamp"),
            "sentimentTimestamp": datetime.utcnow().isoformat(),
            "tickers": tickers_output
        }

        s3.put_object(Bucket=bucket_name, Key=key, Body=json.dumps(ergebnis).encode("utf-8"))
        print(f"✅ Sentiment für {len(tickers_output)} Ticker gespeichert: {key}")

    except Exception as e:
        print(f"❌ Fehler bei Artikelverarbeitung: {e}")


counter = 0

# Haupt-Loop mit Batching & Parallelität
with ThreadPoolExecutor(max_workers=max_workers) as executor:
    while True:
        batch = consumer.poll(timeout_ms=1000, max_records=10)

        futures = []
        for _, messages in batch.items():
            for msg in messages:
                counter += 1
                if msg not in processed:
                    processed.append(msg)
                    print(f'Processing message Nr. {counter}')
                    futures.append(executor.submit(process_article, msg.value))
                else:
                    print(f'Message Nr. {counter} already processed, skipping')

        # Warten, bis alle fertig
        for f in futures:
            f.result()

        # Nach Erfolg Kafka-Offsets committen
        consumer.commit()

# %% [markdown]
# ## Consumer Test

# %%
import json
import boto3
import nltk
from kafka import KafkaConsumer
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
from collections import defaultdict
from nltk.tokenize import PunktSentenceTokenizer
import pandas as pd
from datetime import datetime

nltk.download("punkt")
sentence_tokenizer = PunktSentenceTokenizer()

# 🔃 Ticker + Synonyme laden
ticker_df = pd.read_csv("ticker_synonyme.csv")
ticker_map = defaultdict(set)
for _, row in ticker_df.iterrows():
    ticker_map[row["ticker"]].add(row["synonym"].lower())

# Kafka Consumer
consumer = KafkaConsumer(
    "artikel-sentiment",
    bootstrap_servers="localhost:9092",
    auto_offset_reset="earliest",
    enable_auto_commit=True,
    group_id="finbert-consumer-test",
    value_deserializer=lambda m: json.loads(m.decode("utf-8"))
)

# FinBERT
model_name = "ProsusAI/finbert"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
classifier = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# Konfiguration
max_articles = 10
block_size = 3
min_blocks_per_ticker = 2
min_relevance_score = 0.1

processed = 0

for msg in consumer:
    if processed >= max_articles:
        break

    article = msg.value
    text = article.get("articleText")
    if not text:
        print(f"⚠️ Kein Text vorhanden für: {article.get('source')}")
        continue

    sätze = sentence_tokenizer.tokenize(text)
    if len(sätze) == 0:
        continue

    # Blöcke erzeugen
    blöcke = [sätze[i:i+block_size] for i in range(0, len(sätze), block_size)]
    block_sentences = [" ".join(block) for block in blöcke]

    # Sentiment pro Block
    block_sentiments = classifier(block_sentences, truncation=True)

    # Ticker-Zuordnung
    ticker_to_blocks = defaultdict(list)
    for idx, block in enumerate(blöcke):
        block_text = " ".join(block).lower()
        for ticker, syns in ticker_map.items():
            if any(syn in block_text for syn in syns):
                ticker_to_blocks[ticker].append(idx)

    # Mindestanzahl Blöcke pro Ticker
    ticker_to_blocks = {
        ticker: idxs for ticker, idxs in ticker_to_blocks.items() if len(idxs) >= min_blocks_per_ticker
    }

    if not ticker_to_blocks:
        print(f"ℹ️ Keine ausreichend relevanten Ticker für: {article.get('source')}")
        processed += 1
        continue

    total_blocks = len(blöcke)
    tickers_output = []

    for ticker, idx_list in ticker_to_blocks.items():
        sentiment_sum = 0
        score_sum = 0
        for idx in idx_list:
            result = block_sentiments[idx]
            label_weights = {"positive": 1, "neutral": 0, "negative": -1}
            weight = label_weights[result["label"]]
            sentiment_sum += weight * result["score"]
            score_sum += result["score"]

        weighted_sentiment = sentiment_sum / score_sum if score_sum else 0
        relevance_score = len(idx_list) / total_blocks if total_blocks else 0

        if relevance_score >= min_relevance_score:
            tickers_output.append({
                "ticker": ticker,
                "sentiment_score": round(weighted_sentiment, 3),
                "relevance_score": round(relevance_score, 3)
            })

    if not tickers_output:
        print(f"ℹ️ Keine Ticker mit ausreichender Relevanz für: {article.get('source')}")
    else:
        ergebnis = {
            "url": article.get("url"),
            "articleTimestamp": article.get("articleTimestamp"),
            "scrapingTimestamp": article.get("scrapingTimestamp"),
            "parsingTimestamp": article.get("parsingTimestamp"),
            "sentimentTimestamp": datetime.utcnow().isoformat(),
            "tickers": tickers_output
        }
        print(json.dumps(ergebnis, indent=2))

    processed += 1

print(f"✅ Analyse abgeschlossen für {processed} Artikel.")

# %% [markdown]
# ## Multithreaded on GPU

# %%
import torch
print(torch.cuda.is_available())  # Should return True
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 2060 SUPER

# %%
import json
import boto3
import nltk
import pandas as pd
from kafka import KafkaConsumer
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
from collections import defaultdict
from nltk.tokenize import PunktSentenceTokenizer
from concurrent.futures import ThreadPoolExecutor
from datetime import datetime
import torch


# Setup
nltk.download("punkt")
sentence_tokenizer = PunktSentenceTokenizer()

# Ticker + Synonyme laden
ticker_df = pd.read_csv("ticker_synonyme.csv")
ticker_map = defaultdict(set)
for _, row in ticker_df.iterrows():
    ticker_map[row["ticker"]].add(row["synonym"].lower())

# FinBERT
model_name = "ProsusAI/finbert"
tokenizer = AutoTokenizer.from_pretrained(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = AutoModelForSequenceClassification.from_pretrained(model_name).to(device)

classifier = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer, device=0 if torch.cuda.is_available() else -1)

# 🪣 MinIO
s3 = boto3.client(
    's3',
    endpoint_url='http://172.29.16.105:9000',
    aws_access_key_id='bdenggroup3',
    aws_secret_access_key='bdenggroup3'
)

bucket_name = 'bdenggroup3'
output_prefix = 'sentiment/'

# 🔧 Konfiguration
block_size = 3
min_blocks_per_ticker = 2
min_relevance_score = 0.1
max_workers = 4

# Kafka
consumer = KafkaConsumer(
    "artikel-sentiment",
    bootstrap_servers="localhost:9092",
    auto_offset_reset="earliest",
    enable_auto_commit=False,
    group_id="finbert-consumer",
    value_deserializer=lambda m: json.loads(m.decode("utf-8"))
)


# Verarbeitung eines Artikels
def process_article(article):
    try:
        source_filename = article.get("source", "parsed_unknown.json")
        sentiment_filename = source_filename.replace("parsed_", "sentiment_")
        key = f"{output_prefix}{sentiment_filename}"

        # 🚫 Duplikate überspringen
        try:
            s3.head_object(Bucket=bucket_name, Key=key)
            print(f"⏭️ Bereits verarbeitet, wird übersprungen: {key}")
            return
        except s3.exceptions.ClientError as e:
            if e.response['Error']['Code'] != '404':
                raise

        text = article.get("articleText")
        if not text:
            print(f"⚠️ Kein Text vorhanden für: {article.get('source')}")
            return

        sätze = sentence_tokenizer.tokenize(text)
        if len(sätze) == 0:
            return

        blöcke = [sätze[i:i+block_size] for i in range(0, len(sätze), block_size)]
        block_sentences = [" ".join(block) for block in blöcke]
        total_blocks = len(blöcke)

        block_sentiments = classifier(block_sentences, truncation=True)

        ticker_to_blocks = defaultdict(list)
        for idx, block in enumerate(blöcke):
            block_text = " ".join(block).lower()
            for ticker, syns in ticker_map.items():
                if any(syn in block_text for syn in syns):
                    ticker_to_blocks[ticker].append(idx)

        ticker_to_blocks = {
            ticker: idxs for ticker, idxs in ticker_to_blocks.items()
            if len(idxs) >= min_blocks_per_ticker
        }

        if not ticker_to_blocks:
            print(f"ℹ️ Keine ausreichend relevanten Ticker für: {article.get('source')}")
            return

        tickers_output = []
        for ticker, idx_list in ticker_to_blocks.items():
            sentiment_sum = 0
            score_sum = 0
            for idx in idx_list:
                result = block_sentiments[idx]
                weight = {"positive": 1, "neutral": 0, "negative": -1}[result["label"]]
                sentiment_sum += weight * result["score"]
                score_sum += result["score"]

            weighted_sentiment = sentiment_sum / score_sum if score_sum else 0
            relevance_score = len(idx_list) / total_blocks if total_blocks else 0

            if relevance_score >= min_relevance_score:
                tickers_output.append({
                    "ticker": ticker,
                    "sentiment_score": round(weighted_sentiment, 3),
                    "relevance_score": round(relevance_score, 3)
                })

        if not tickers_output:
            print(f"ℹ️ Keine Ticker mit ausreichender Relevanz für: {article.get('source')}")
            return

        ergebnis = {
            "url": article.get("url"),
            "articleTimestamp": article.get("articleTimestamp"),
            "scrapingTimestamp": article.get("scrapingTimestamp"),
            "parsingTimestamp": article.get("parsingTimestamp"),
            "sentimentTimestamp": datetime.utcnow().isoformat(),
            "tickers": tickers_output
        }

        s3.put_object(Bucket=bucket_name, Key=key, Body=json.dumps(ergebnis).encode("utf-8"))
        print(f"✅ Sentiment für {len(tickers_output)} Ticker gespeichert: {key}")

    except Exception as e:
        print(f"❌ Fehler bei Artikelverarbeitung: {e}")

counter = 0

# Haupt-Loop mit Batching & Parallelität
with ThreadPoolExecutor(max_workers=max_workers) as executor:
    while True:
        batch = consumer.poll(timeout_ms=1000, max_records=200)

        futures = []
        for _, messages in batch.items():
            for msg in messages:
                counter += 1
                print(f'Processing message Nr. {counter}')
                futures.append(executor.submit(process_article, msg.value))

        # Warten, bis alle fertig
        for f in futures:
            f.result()

        # Nach Erfolg Kafka-Offsets committen
        consumer.commit()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Michael\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# C:\Users\Michael\DataspellProjects\fhtw-bdeng-project\.venv\Lib\site-packages\huggingface_hub\file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing message Nr. 1
# Processing message Nr. 2
# Processing message Nr. 3
# Processing message Nr. 4
# Processing message Nr. 5
# Processing message Nr. 6
# Processing message Nr. 7
# Processing message Nr. 8
# Processing message Nr. 9
# Processing message Nr. 10
# Processing message Nr. 11
# Processing message Nr. 12
# Processing message Nr. 13
# Processing message Nr. 14
# Processing message Nr. 15
# Processing message Nr. 16
# Processing message Nr. 17
# Processing message Nr. 18
# Processing message Nr. 19
# Processing message Nr. 20
# Processing message Nr. 21
# Processing message Nr. 22
# Processing message Nr. 23
# Processing message Nr. 24
# Processing message Nr. 25
# Processing message Nr. 26
# Processing message Nr. 27
# Processing message Nr. 28
# Processing message Nr. 29
# Processing message Nr. 30
# Processing message Nr. 31
# Processing message Nr. 32
# Processing message Nr. 33
# Processing message Nr. 34
# Processing message Nr. 35
# Processing message Nr. 36
# Processing message Nr. 37
# Processing message Nr. 38
# Processing message Nr. 39
# Processing message Nr. 40
# Processing message Nr. 41
# Processing message Nr. 42
# Processing message Nr. 43
# Processing message Nr. 44
# Processing message Nr. 45
# Processing message Nr. 46
# Processing message Nr. 47
# Processing message Nr. 48
# Processing message Nr. 49
# Processing message Nr. 50
# Processing message Nr. 51
# Processing message Nr. 52
# Processing message Nr. 53
# Processing message Nr. 54
# Processing message Nr. 55
# Processing message Nr. 56
# Processing message Nr. 57
# Processing message Nr. 58
# Processing message Nr. 59
# Processing message Nr. 60
# Processing message Nr. 61
# Processing message Nr. 62
# Processing message Nr. 63
# Processing message Nr. 64
# Processing message Nr. 65
# Processing message Nr. 66
# Processing message Nr. 67
# Processing message Nr. 68
# Processing message Nr. 69
# Processing message Nr. 70
# Processing message Nr. 71
# Processing message Nr. 72
# Processing message Nr. 73
# Processing message Nr. 74
# Processing message Nr. 75
# Processing message Nr. 76
# Processing message Nr. 77
# Processing message Nr. 78
# Processing message Nr. 79
# Processing message Nr. 80
# Processing message Nr. 81
# Processing message Nr. 82
# Processing message Nr. 83
# Processing message Nr. 84
# Processing message Nr. 85
# Processing message Nr. 86
# Processing message Nr. 87
# Processing message Nr. 88
# Processing message Nr. 89
# Processing message Nr. 90
# Processing message Nr. 91
# Processing message Nr. 92
# Processing message Nr. 93
# Processing message Nr. 94
# Processing message Nr. 95
# Processing message Nr. 96
# Processing message Nr. 97
# Processing message Nr. 98
# Processing message Nr. 99
# Processing message Nr. 100
# Processing message Nr. 101
# Processing message Nr. 102
# Processing message Nr. 103
# Processing message Nr. 104
# Processing message Nr. 105
# Processing message Nr. 106
# Processing message Nr. 107
# Processing message Nr. 108
# Processing message Nr. 109
# Processing message Nr. 110
# Processing message Nr. 111
# Processing message Nr. 112
# Processing message Nr. 113
# Processing message Nr. 114
# Processing message Nr. 115
# Processing message Nr. 116
# Processing message Nr. 117
# Processing message Nr. 118
# Processing message Nr. 119
# Processing message Nr. 120
# Processing message Nr. 121
# Processing message Nr. 122
# Processing message Nr. 123
# Processing message Nr. 124
# Processing message Nr. 125
# Processing message Nr. 126
# Processing message Nr. 127
# Processing message Nr. 128
# Processing message Nr. 129
# Processing message Nr. 130
# Processing message Nr. 131
# Processing message Nr. 132
# Processing message Nr. 133
# Processing message Nr. 134
# Processing message Nr. 135
# Processing message Nr. 136
# Processing message Nr. 137
# Processing message Nr. 138
# Processing message Nr. 139
# Processing message Nr. 140
# Processing message Nr. 141
# Processing message Nr. 142
# Processing message Nr. 143
# Processing message Nr. 144
# Processing message Nr. 145
# Processing message Nr. 146
# Processing message Nr. 147
# Processing message Nr. 148
# Processing message Nr. 149
# Processing message Nr. 150
# Processing message Nr. 151
# Processing message Nr. 152
# Processing message Nr. 153
# Processing message Nr. 154
# Processing message Nr. 155
# Processing message Nr. 156
# Processing message Nr. 157
# Processing message Nr. 158
# Processing message Nr. 159
# Processing message Nr. 160
# Processing message Nr. 161
# Processing message Nr. 162
# Processing message Nr. 163
# Processing message Nr. 164
# Processing message Nr. 165
# Processing message Nr. 166
# Processing message Nr. 167
# Processing message Nr. 168
# Processing message Nr. 169
# Processing message Nr. 170
# Processing message Nr. 171
# Processing message Nr. 172
# Processing message Nr. 173
# Processing message Nr. 174
# Processing message Nr. 175
# Processing message Nr. 176
# Processing message Nr. 177
# Processing message Nr. 178
# Processing message Nr. 179
# Processing message Nr. 180
# Processing message Nr. 181
# Processing message Nr. 182
# Processing message Nr. 183
# Processing message Nr. 184
# Processing message Nr. 185
# Processing message Nr. 186
# Processing message Nr. 187
# Processing message Nr. 188
# Processing message Nr. 189
# Processing message Nr. 190
# Processing message Nr. 191
# Processing message Nr. 192
# Processing message Nr. 193
# Processing message Nr. 194
# Processing message Nr. 195
# Processing message Nr. 196
# Processing message Nr. 197
# Processing message Nr. 198
# Processing message Nr. 199
# Processing message Nr. 200
# Processing message Nr. 201
# Processing message Nr. 202
# Processing message Nr. 203
# Processing message Nr. 204
# Processing message Nr. 205
# ⏭️ Bereits verarbeitet, wird übersprungen: sentiment/sentiment_15554.json
# ⏭️ Bereits verarbeitet, wird übersprungen: sentiment/sentiment_15553.json
# ⏭️ Bereits verarbeitet, wird übersprungen: sentiment/sentiment_15555.json
# ⏭️ Bereits verarbeitet, wird übersprungen: sentiment/sentiment_15557.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15556.json
# ⏭️ Bereits verarbeitet, wird übersprungen: sentiment/sentiment_15560.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15559.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15558.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1556.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15562.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15561.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15564.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15563.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15565.json
# C:\Users\Michael\DataspellProjects\fhtw-bdeng-project\.venv\Lib\site-packages\transformers\pipelines\base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# C:\Users\Michael\AppData\Local\Temp\ipykernel_22372\1982841478.py:137: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "sentimentTimestamp": datetime.utcnow().isoformat(),
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15566.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15567.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15569.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15568.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15570.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15571.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15572.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15573.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15574.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15576.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15578.json
# ℹ️ Keine Ticker mit ausreichender Relevanz für: parsed_1557.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15577.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1558.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15575.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15579.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15581.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15580.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15583.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15582.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15584.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15586.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15585.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1559.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15588.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15589.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15587.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15591.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15590.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15592.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15593.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15594.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15595.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15596.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15597.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_156.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15599.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15598.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_1560.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15600.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15601.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15603.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15602.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15604.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15605.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15606.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15608.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15607.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1561.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15609.json
# ✅ Sentiment für 2 Ticker gespeichert: sentiment/sentiment_15611.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15613.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15612.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15610.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15615.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15617.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15614.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15616.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15619.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15618.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1562.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15620.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15622.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15621.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15624.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15623.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15625.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15626.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15628.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15629.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15627.json
# ✅ Sentiment für 2 Ticker gespeichert: sentiment/sentiment_1563.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15630.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15633.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15631.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15632.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15634.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15637.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15635.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15636.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15638.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_1564.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15639.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15640.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15641.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15642.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15643.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15644.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15645.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15646.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15648.json
# ⚠️ Kein Text vorhanden für: parsed_15650.json
# ✅ Sentiment für 2 Ticker gespeichert: sentiment/sentiment_1565.json
# ✅ Sentiment für 3 Ticker gespeichert: sentiment/sentiment_15647.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15649.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15651.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15652.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15653.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15655.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15654.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15657.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15656.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15659.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1566.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15658.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15661.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15662.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15663.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15660.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15665.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15664.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15667.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15668.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1567.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15669.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15666.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15672.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15670.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15671.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15673.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15676.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15674.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15675.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15677.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1568.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15678.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15679.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15681.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15680.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15682.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15683.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15684.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15686.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15685.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1569.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15687.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15689.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15688.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15690.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15692.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15691.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15693.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15694.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15695.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15696.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15697.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_157.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15699.json
# ✅ Sentiment für 4 Ticker gespeichert: sentiment/sentiment_1570.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15698.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15703.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15702.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15700.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15705.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15701.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15704.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15707.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15706.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1571.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15708.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15710.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15709.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15711.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15713.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15712.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15714.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15715.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15717.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15716.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15718.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15719.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_1572.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15720.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15721.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15722.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15725.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15723.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15726.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15727.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15724.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15728.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1573.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15729.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15730.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15731.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15733.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15732.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15734.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15735.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15737.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15736.json
# Processing message Nr. 206
# Processing message Nr. 207
# Processing message Nr. 208
# Processing message Nr. 209
# Processing message Nr. 210
# Processing message Nr. 211
# Processing message Nr. 212
# Processing message Nr. 213
# Processing message Nr. 214
# Processing message Nr. 215
# Processing message Nr. 216
# Processing message Nr. 217
# Processing message Nr. 218
# Processing message Nr. 219
# Processing message Nr. 220
# Processing message Nr. 221
# Processing message Nr. 222
# Processing message Nr. 223
# Processing message Nr. 224
# Processing message Nr. 225
# Processing message Nr. 226
# Processing message Nr. 227
# Processing message Nr. 228
# Processing message Nr. 229
# Processing message Nr. 230
# Processing message Nr. 231
# Processing message Nr. 232
# Processing message Nr. 233
# Processing message Nr. 234
# Processing message Nr. 235
# Processing message Nr. 236
# Processing message Nr. 237
# Processing message Nr. 238
# Processing message Nr. 239
# Processing message Nr. 240
# Processing message Nr. 241
# Processing message Nr. 242
# Processing message Nr. 243
# Processing message Nr. 244
# Processing message Nr. 245
# Processing message Nr. 246
# Processing message Nr. 247
# Processing message Nr. 248
# Processing message Nr. 249
# Processing message Nr. 250
# Processing message Nr. 251
# Processing message Nr. 252
# Processing message Nr. 253
# Processing message Nr. 254
# Processing message Nr. 255
# Processing message Nr. 256
# Processing message Nr. 257
# Processing message Nr. 258
# Processing message Nr. 259
# Processing message Nr. 260
# Processing message Nr. 261
# Processing message Nr. 262
# Processing message Nr. 263
# Processing message Nr. 264
# Processing message Nr. 265
# Processing message Nr. 266
# Processing message Nr. 267
# Processing message Nr. 268
# Processing message Nr. 269
# Processing message Nr. 270
# Processing message Nr. 271
# Processing message Nr. 272
# Processing message Nr. 273
# Processing message Nr. 274
# Processing message Nr. 275
# Processing message Nr. 276
# Processing message Nr. 277
# Processing message Nr. 278
# Processing message Nr. 279
# Processing message Nr. 280
# Processing message Nr. 281
# Processing message Nr. 282
# Processing message Nr. 283
# Processing message Nr. 284
# Processing message Nr. 285
# Processing message Nr. 286
# Processing message Nr. 287
# Processing message Nr. 288
# Processing message Nr. 289
# Processing message Nr. 290
# Processing message Nr. 291
# Processing message Nr. 292
# Processing message Nr. 293
# Processing message Nr. 294
# Processing message Nr. 295
# Processing message Nr. 296
# Processing message Nr. 297
# Processing message Nr. 298
# Processing message Nr. 299
# Processing message Nr. 300
# Processing message Nr. 301
# Processing message Nr. 302
# Processing message Nr. 303
# Processing message Nr. 304
# Processing message Nr. 305
# Processing message Nr. 306
# Processing message Nr. 307
# Processing message Nr. 308
# Processing message Nr. 309
# Processing message Nr. 310
# Processing message Nr. 311
# Processing message Nr. 312
# Processing message Nr. 313
# Processing message Nr. 314
# Processing message Nr. 315
# Processing message Nr. 316
# Processing message Nr. 317
# Processing message Nr. 318
# Processing message Nr. 319
# Processing message Nr. 320
# Processing message Nr. 321
# Processing message Nr. 322
# Processing message Nr. 323
# Processing message Nr. 324
# Processing message Nr. 325
# Processing message Nr. 326
# Processing message Nr. 327
# Processing message Nr. 328
# Processing message Nr. 329
# Processing message Nr. 330
# Processing message Nr. 331
# Processing message Nr. 332
# Processing message Nr. 333
# Processing message Nr. 334
# Processing message Nr. 335
# Processing message Nr. 336
# Processing message Nr. 337
# Processing message Nr. 338
# Processing message Nr. 339
# Processing message Nr. 340
# Processing message Nr. 341
# Processing message Nr. 342
# Processing message Nr. 343
# Processing message Nr. 344
# Processing message Nr. 345
# Processing message Nr. 346
# Processing message Nr. 347
# Processing message Nr. 348
# Processing message Nr. 349
# Processing message Nr. 350
# Processing message Nr. 351
# Processing message Nr. 352
# Processing message Nr. 353
# Processing message Nr. 354
# Processing message Nr. 355
# Processing message Nr. 356
# Processing message Nr. 357
# Processing message Nr. 358
# Processing message Nr. 359
# Processing message Nr. 360
# Processing message Nr. 361
# Processing message Nr. 362
# Processing message Nr. 363
# Processing message Nr. 364
# Processing message Nr. 365
# Processing message Nr. 366
# Processing message Nr. 367
# Processing message Nr. 368
# Processing message Nr. 369
# Processing message Nr. 370
# Processing message Nr. 371
# Processing message Nr. 372
# Processing message Nr. 373
# Processing message Nr. 374
# Processing message Nr. 375
# Processing message Nr. 376
# Processing message Nr. 377
# Processing message Nr. 378
# Processing message Nr. 379
# Processing message Nr. 380
# Processing message Nr. 381
# Processing message Nr. 382
# Processing message Nr. 383
# Processing message Nr. 384
# Processing message Nr. 385
# Processing message Nr. 386
# Processing message Nr. 387
# Processing message Nr. 388
# Processing message Nr. 389
# Processing message Nr. 390
# Processing message Nr. 391
# Processing message Nr. 392
# Processing message Nr. 393
# Processing message Nr. 394
# Processing message Nr. 395
# Processing message Nr. 396
# Processing message Nr. 397
# Processing message Nr. 398
# Processing message Nr. 399
# Processing message Nr. 400
# Processing message Nr. 401
# Processing message Nr. 402
# Processing message Nr. 403
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15740.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1574.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15739.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15741.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15742.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15738.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15744.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15743.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15746.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15745.json
# ✅ Sentiment für 2 Ticker gespeichert: sentiment/sentiment_1575.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15748.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15747.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15749.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15750.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15752.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15751.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15753.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15754.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15755.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15756.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15757.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15759.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15761.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1576.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15760.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15758.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15762.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15763.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15764.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15766.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15767.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15765.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15768.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_1577.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15769.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15770.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15771.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15772.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15774.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15775.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15773.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15776.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15778.json
# ✅ Sentiment für 2 Ticker gespeichert: sentiment/sentiment_15779.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15777.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1578.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15780.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15781.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15782.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15783.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15787.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15785.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15784.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15786.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15788.json
# ✅ Sentiment für 4 Ticker gespeichert: sentiment/sentiment_1579.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15790.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15789.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15791.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15792.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15793.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15794.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15796.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15797.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15798.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15795.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15799.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1580.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_158.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15800.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15802.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15803.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15801.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15804.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15805.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15806.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15807.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15808.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1581.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15810.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15811.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15809.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15813.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15812.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15815.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15814.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15816.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15817.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15818.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15819.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1582.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15821.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15823.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15822.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15820.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15825.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15824.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15826.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15827.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15829.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1583.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15830.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15833.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15828.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15831.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15832.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15835.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15834.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15836.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15839.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15838.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15837.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1584.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15840.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15841.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15842.json
# ⚠️ Kein Text vorhanden für: parsed_15846.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15843.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15844.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15845.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15848.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15847.json
# ✅ Sentiment für 2 Ticker gespeichert: sentiment/sentiment_1585.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15849.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15850.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15851.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15853.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15852.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15854.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15856.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15855.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1586.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15857.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15859.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15858.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15861.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15863.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15862.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15860.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15864.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15865.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15866.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15867.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15869.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15868.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_1587.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15870.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15872.json
# ℹ️ Keine Ticker mit ausreichender Relevanz für: parsed_15871.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15874.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15873.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15875.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15876.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15877.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15878.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1588.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15879.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15880.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15881.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15883.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15882.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15884.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15887.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15885.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15886.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_1589.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15888.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15889.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15890.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15891.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15892.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15893.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15894.json
# ⚠️ Kein Text vorhanden für: parsed_15898.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15896.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15895.json
# ℹ️ Keine Ticker mit ausreichender Relevanz für: parsed_15897.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_159.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15899.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15902.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15901.json
# ✅ Sentiment für 4 Ticker gespeichert: sentiment/sentiment_1590.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15900.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15903.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15906.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15905.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15904.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1591.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15907.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15908.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15909.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15910.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15913.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15911.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15912.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15914.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15915.json
# Processing message Nr. 404
# Processing message Nr. 405
# Processing message Nr. 406
# Processing message Nr. 407
# Processing message Nr. 408
# Processing message Nr. 409
# Processing message Nr. 410
# Processing message Nr. 411
# Processing message Nr. 412
# Processing message Nr. 413
# Processing message Nr. 414
# Processing message Nr. 415
# Processing message Nr. 416
# Processing message Nr. 417
# Processing message Nr. 418
# Processing message Nr. 419
# Processing message Nr. 420
# Processing message Nr. 421
# Processing message Nr. 422
# Processing message Nr. 423
# Processing message Nr. 424
# Processing message Nr. 425
# Processing message Nr. 426
# Processing message Nr. 427
# Processing message Nr. 428
# Processing message Nr. 429
# Processing message Nr. 430
# Processing message Nr. 431
# Processing message Nr. 432
# Processing message Nr. 433
# Processing message Nr. 434
# Processing message Nr. 435
# Processing message Nr. 436
# Processing message Nr. 437
# Processing message Nr. 438
# Processing message Nr. 439
# Processing message Nr. 440
# Processing message Nr. 441
# Processing message Nr. 442
# Processing message Nr. 443
# Processing message Nr. 444
# Processing message Nr. 445
# Processing message Nr. 446
# Processing message Nr. 447
# Processing message Nr. 448
# Processing message Nr. 449
# Processing message Nr. 450
# Processing message Nr. 451
# Processing message Nr. 452
# Processing message Nr. 453
# Processing message Nr. 454
# Processing message Nr. 455
# Processing message Nr. 456
# Processing message Nr. 457
# Processing message Nr. 458
# Processing message Nr. 459
# Processing message Nr. 460
# Processing message Nr. 461
# Processing message Nr. 462
# Processing message Nr. 463
# Processing message Nr. 464
# Processing message Nr. 465
# Processing message Nr. 466
# Processing message Nr. 467
# Processing message Nr. 468
# Processing message Nr. 469
# Processing message Nr. 470
# Processing message Nr. 471
# Processing message Nr. 472
# Processing message Nr. 473
# Processing message Nr. 474
# Processing message Nr. 475
# Processing message Nr. 476
# Processing message Nr. 477
# Processing message Nr. 478
# Processing message Nr. 479
# Processing message Nr. 480
# Processing message Nr. 481
# Processing message Nr. 482
# Processing message Nr. 483
# Processing message Nr. 484
# Processing message Nr. 485
# Processing message Nr. 486
# Processing message Nr. 487
# Processing message Nr. 488
# Processing message Nr. 489
# Processing message Nr. 490
# Processing message Nr. 491
# Processing message Nr. 492
# Processing message Nr. 493
# Processing message Nr. 494
# Processing message Nr. 495
# Processing message Nr. 496
# Processing message Nr. 497
# Processing message Nr. 498
# Processing message Nr. 499
# Processing message Nr. 500
# Processing message Nr. 501
# Processing message Nr. 502
# Processing message Nr. 503
# Processing message Nr. 504
# Processing message Nr. 505
# Processing message Nr. 506
# Processing message Nr. 507
# Processing message Nr. 508
# Processing message Nr. 509
# Processing message Nr. 510
# Processing message Nr. 511
# Processing message Nr. 512
# Processing message Nr. 513
# Processing message Nr. 514
# Processing message Nr. 515
# Processing message Nr. 516
# Processing message Nr. 517
# Processing message Nr. 518
# Processing message Nr. 519
# Processing message Nr. 520
# Processing message Nr. 521
# Processing message Nr. 522
# Processing message Nr. 523
# Processing message Nr. 524
# Processing message Nr. 525
# Processing message Nr. 526
# Processing message Nr. 527
# Processing message Nr. 528
# Processing message Nr. 529
# Processing message Nr. 530
# Processing message Nr. 531
# Processing message Nr. 532
# Processing message Nr. 533
# Processing message Nr. 534
# Processing message Nr. 535
# Processing message Nr. 536
# Processing message Nr. 537
# Processing message Nr. 538
# Processing message Nr. 539
# Processing message Nr. 540
# Processing message Nr. 541
# Processing message Nr. 542
# Processing message Nr. 543
# Processing message Nr. 544
# Processing message Nr. 545
# Processing message Nr. 546
# Processing message Nr. 547
# Processing message Nr. 548
# Processing message Nr. 549
# Processing message Nr. 550
# Processing message Nr. 551
# Processing message Nr. 552
# Processing message Nr. 553
# Processing message Nr. 554
# Processing message Nr. 555
# Processing message Nr. 556
# Processing message Nr. 557
# Processing message Nr. 558
# Processing message Nr. 559
# Processing message Nr. 560
# Processing message Nr. 561
# Processing message Nr. 562
# Processing message Nr. 563
# Processing message Nr. 564
# Processing message Nr. 565
# Processing message Nr. 566
# Processing message Nr. 567
# Processing message Nr. 568
# Processing message Nr. 569
# Processing message Nr. 570
# Processing message Nr. 571
# Processing message Nr. 572
# Processing message Nr. 573
# Processing message Nr. 574
# Processing message Nr. 575
# Processing message Nr. 576
# Processing message Nr. 577
# Processing message Nr. 578
# Processing message Nr. 579
# Processing message Nr. 580
# Processing message Nr. 581
# Processing message Nr. 582
# Processing message Nr. 583
# Processing message Nr. 584
# Processing message Nr. 585
# Processing message Nr. 586
# Processing message Nr. 587
# Processing message Nr. 588
# Processing message Nr. 589
# Processing message Nr. 590
# Processing message Nr. 591
# Processing message Nr. 592
# Processing message Nr. 593
# Processing message Nr. 594
# Processing message Nr. 595
# Processing message Nr. 596
# Processing message Nr. 597
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15917.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15918.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15919.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1592.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15916.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15921.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15920.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15922.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15923.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15925.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15924.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15927.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15926.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15928.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15929.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15930.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1593.json
# ✅ Sentiment für 2 Ticker gespeichert: sentiment/sentiment_15932.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15931.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15933.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15936.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15934.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15935.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15937.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15938.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15939.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1594.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15941.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15940.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15943.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15942.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15944.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15946.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15945.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15947.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15948.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_1595.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15949.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15950.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15951.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15952.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15953.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15955.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15954.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15957.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15956.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1596.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15959.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15958.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15960.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15964.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15961.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15962.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15963.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15968.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15966.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15965.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15967.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1597.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15969.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15970.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15971.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15972.json
# ⚠️ Kein Text vorhanden für: parsed_15976.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15973.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15974.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15978.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15975.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15977.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15979.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1598.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15980.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15982.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15983.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15981.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15984.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15985.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15986.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15987.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_1599.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15988.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15990.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15991.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15989.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_15992.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15995.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_15994.json
# ...
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26476.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26475.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26477.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26479.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_2648.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26480.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26478.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26481.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26483.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26484.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26485.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26487.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26486.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26488.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26489.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_2649.json
# ✅ Sentiment für 2 Ticker gespeichert: sentiment/sentiment_26490.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26491.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26482.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26493.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26492.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26494.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26497.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26496.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26498.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_2650.json
# ℹ️ Keine Ticker mit ausreichender Relevanz für: parsed_26495.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_265.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26499.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26500.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26501.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26502.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26504.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26503.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26505.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26506.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26509.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_2651.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26507.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26511.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26508.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26512.json
# ℹ️ Keine Ticker mit ausreichender Relevanz für: parsed_26510.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26514.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26515.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26513.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26518.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26516.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26517.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_2652.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26520.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26523.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26519.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26521.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26522.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26526.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26524.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26525.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26529.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26527.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26528.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_2653.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26531.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26533.json
# ✅ Sentiment für 2 Ticker gespeichert: sentiment/sentiment_26532.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26530.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26534.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26536.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26535.json
# ✅ Sentiment für 2 Ticker gespeichert: sentiment/sentiment_26538.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26537.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26539.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_2654.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26541.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26543.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26542.json
# ✅ Sentiment für 4 Ticker gespeichert: sentiment/sentiment_26540.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26544.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26545.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26546.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26548.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_2655.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26549.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26547.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26550.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26551.json
# Processing message Nr. 12222
# Processing message Nr. 12223
# Processing message Nr. 12224
# Processing message Nr. 12225
# Processing message Nr. 12226
# Processing message Nr. 12227
# Processing message Nr. 12228
# Processing message Nr. 12229
# Processing message Nr. 12230
# Processing message Nr. 12231
# Processing message Nr. 12232
# Processing message Nr. 12233
# Processing message Nr. 12234
# Processing message Nr. 12235
# Processing message Nr. 12236
# Processing message Nr. 12237
# Processing message Nr. 12238
# Processing message Nr. 12239
# Processing message Nr. 12240
# Processing message Nr. 12241
# Processing message Nr. 12242
# Processing message Nr. 12243
# Processing message Nr. 12244
# Processing message Nr. 12245
# Processing message Nr. 12246
# Processing message Nr. 12247
# Processing message Nr. 12248
# Processing message Nr. 12249
# Processing message Nr. 12250
# Processing message Nr. 12251
# Processing message Nr. 12252
# Processing message Nr. 12253
# Processing message Nr. 12254
# Processing message Nr. 12255
# Processing message Nr. 12256
# Processing message Nr. 12257
# Processing message Nr. 12258
# Processing message Nr. 12259
# Processing message Nr. 12260
# Processing message Nr. 12261
# Processing message Nr. 12262
# Processing message Nr. 12263
# Processing message Nr. 12264
# Processing message Nr. 12265
# Processing message Nr. 12266
# Processing message Nr. 12267
# Processing message Nr. 12268
# Processing message Nr. 12269
# Processing message Nr. 12270
# Processing message Nr. 12271
# Processing message Nr. 12272
# Processing message Nr. 12273
# Processing message Nr. 12274
# Processing message Nr. 12275
# Processing message Nr. 12276
# Processing message Nr. 12277
# Processing message Nr. 12278
# Processing message Nr. 12279
# Processing message Nr. 12280
# Processing message Nr. 12281
# Processing message Nr. 12282
# Processing message Nr. 12283
# Processing message Nr. 12284
# Processing message Nr. 12285
# Processing message Nr. 12286
# Processing message Nr. 12287
# Processing message Nr. 12288
# Processing message Nr. 12289
# Processing message Nr. 12290
# Processing message Nr. 12291
# Processing message Nr. 12292
# Processing message Nr. 12293
# Processing message Nr. 12294
# Processing message Nr. 12295
# Processing message Nr. 12296
# Processing message Nr. 12297
# Processing message Nr. 12298
# Processing message Nr. 12299
# Processing message Nr. 12300
# Processing message Nr. 12301
# Processing message Nr. 12302
# Processing message Nr. 12303
# Processing message Nr. 12304
# Processing message Nr. 12305
# Processing message Nr. 12306
# Processing message Nr. 12307
# Processing message Nr. 12308
# Processing message Nr. 12309
# Processing message Nr. 12310
# Processing message Nr. 12311
# Processing message Nr. 12312
# Processing message Nr. 12313
# Processing message Nr. 12314
# Processing message Nr. 12315
# Processing message Nr. 12316
# Processing message Nr. 12317
# Processing message Nr. 12318
# Processing message Nr. 12319
# Processing message Nr. 12320
# Processing message Nr. 12321
# Processing message Nr. 12322
# Processing message Nr. 12323
# Processing message Nr. 12324
# Processing message Nr. 12325
# Processing message Nr. 12326
# Processing message Nr. 12327
# Processing message Nr. 12328
# Processing message Nr. 12329
# Processing message Nr. 12330
# Processing message Nr. 12331
# Processing message Nr. 12332
# Processing message Nr. 12333
# Processing message Nr. 12334
# Processing message Nr. 12335
# Processing message Nr. 12336
# Processing message Nr. 12337
# Processing message Nr. 12338
# Processing message Nr. 12339
# Processing message Nr. 12340
# Processing message Nr. 12341
# Processing message Nr. 12342
# Processing message Nr. 12343
# Processing message Nr. 12344
# Processing message Nr. 12345
# Processing message Nr. 12346
# Processing message Nr. 12347
# Processing message Nr. 12348
# Processing message Nr. 12349
# Processing message Nr. 12350
# Processing message Nr. 12351
# Processing message Nr. 12352
# Processing message Nr. 12353
# Processing message Nr. 12354
# Processing message Nr. 12355
# Processing message Nr. 12356
# Processing message Nr. 12357
# Processing message Nr. 12358
# Processing message Nr. 12359
# Processing message Nr. 12360
# Processing message Nr. 12361
# Processing message Nr. 12362
# Processing message Nr. 12363
# Processing message Nr. 12364
# Processing message Nr. 12365
# Processing message Nr. 12366
# Processing message Nr. 12367
# Processing message Nr. 12368
# Processing message Nr. 12369
# Processing message Nr. 12370
# Processing message Nr. 12371
# Processing message Nr. 12372
# Processing message Nr. 12373
# Processing message Nr. 12374
# Processing message Nr. 12375
# Processing message Nr. 12376
# Processing message Nr. 12377
# Processing message Nr. 12378
# Processing message Nr. 12379
# Processing message Nr. 12380
# Processing message Nr. 12381
# Processing message Nr. 12382
# Processing message Nr. 12383
# Processing message Nr. 12384
# Processing message Nr. 12385
# Processing message Nr. 12386
# Processing message Nr. 12387
# Processing message Nr. 12388
# Processing message Nr. 12389
# Processing message Nr. 12390
# Processing message Nr. 12391
# Processing message Nr. 12392
# Processing message Nr. 12393
# Processing message Nr. 12394
# Processing message Nr. 12395
# Processing message Nr. 12396
# Processing message Nr. 12397
# Processing message Nr. 12398
# Processing message Nr. 12399
# Processing message Nr. 12400
# Processing message Nr. 12401
# Processing message Nr. 12402
# Processing message Nr. 12403
# Processing message Nr. 12404
# Processing message Nr. 12405
# Processing message Nr. 12406
# Processing message Nr. 12407
# Processing message Nr. 12408
# Processing message Nr. 12409
# Processing message Nr. 12410
# Processing message Nr. 12411
# Processing message Nr. 12412
# Processing message Nr. 12413
# Processing message Nr. 12414
# Processing message Nr. 12415
# Processing message Nr. 12416
# Processing message Nr. 12417
# Processing message Nr. 12418
# Processing message Nr. 12419
# Processing message Nr. 12420
# Processing message Nr. 12421
# Processing message Nr. 12422
# Processing message Nr. 12423
# Processing message Nr. 12424
# Processing message Nr. 12425
# Processing message Nr. 12426
# Processing message Nr. 12427
# Processing message Nr. 12428
# Processing message Nr. 12429
# Processing message Nr. 12430
# Processing message Nr. 12431
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26553.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26555.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26552.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26557.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26554.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26556.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26559.json
# ✅ Sentiment für 2 Ticker gespeichert: sentiment/sentiment_2656.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26562.json
# ✅ Sentiment für 2 Ticker gespeichert: sentiment/sentiment_26558.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26563.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26561.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26560.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26564.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26565.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26566.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_2657.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26569.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26568.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26567.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26571.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26572.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26574.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26573.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26577.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26575.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26570.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26578.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26576.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26579.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_2658.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26580.json
# ✅ Sentiment für 2 Ticker gespeichert: sentiment/sentiment_26582.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26583.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26585.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26587.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26586.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26584.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26581.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26588.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26590.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26589.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_2659.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26591.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26592.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26593.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26594.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26595.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26596.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_266.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26598.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26599.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26597.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_2660.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26601.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26600.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26602.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26603.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26604.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26605.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26607.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26608.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26606.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_26609.json
# ✅ Sentiment für 1 Ticker gespeichert: sentiment/sentiment_2661.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26610.json
# ℹ️ Keine ausreichend relevanten Ticker für: parsed_26611.json
